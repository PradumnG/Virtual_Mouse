# %%
import cv2
import mediapipe as mp
import pyautogui

# Get screen size
screen_width, screen_height = pyautogui.size()

# Initialize MediaPipe Hands
mpHands = mp.solutions.hands
hands = mpHands.Hands(
    static_image_mode=False,
    model_complexity=1,
    min_detection_confidence=0.7,
    min_tracking_confidence=0.7,
    max_num_hands=1
)

def move_mouse(index_finger_tip):
    if index_finger_tip is not None:
        x = int(index_finger_tip.x * screen_width)
        y = int(index_finger_tip.y * screen_height)
        x = min(max(x, 0), screen_width)
        y = min(max(y, 0), screen_height)
        pyautogui.moveTo(x, y)
        print(f"Moving mouse to ({x}, {y})")  # Debug print statement

def main():
    cap = cv2.VideoCapture(0)
    draw = mp.solutions.drawing_utils

    try:
        while cap.isOpened():
            ret, frame = cap.read()

            if not ret:
                break

            frame = cv2.flip(frame, 1)
            frameRGB = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            processed = hands.process(frameRGB)

            if processed.multi_hand_landmarks:
                hand_landmarks = processed.multi_hand_landmarks[0]
                draw.draw_landmarks(frame, hand_landmarks, mpHands.HAND_CONNECTIONS)

                index_finger_tip = hand_landmarks.landmark[mpHands.HandLandmark.INDEX_FINGER_TIP]
                move_mouse(index_finger_tip)

            cv2.imshow('Frame', frame)
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break

    finally:
        cap.release()
        cv2.destroyAllWindows()

if __name__ == '__main__':
    main()
# Out:
# C:\Users\pradu\AppData\Roaming\Python\Python312\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# Moving mouse to (1038, 678)
# Moving mouse to (1043, 666)
# Moving mouse to (1044, 663)
# Moving mouse to (1042, 663)
# Moving mouse to (1060, 662)
# Moving mouse to (1041, 676)
# Moving mouse to (1048, 671)
# Moving mouse to (1032, 672)
# Moving mouse to (1024, 677)
# Moving mouse to (1048, 673)
# Moving mouse to (1033, 679)
# Moving mouse to (1033, 676)
# Moving mouse to (1040, 680)
# Moving mouse to (1056, 667)
# Moving mouse to (1040, 672)
# Moving mouse to (1032, 679)
# Moving mouse to (1031, 683)
# Moving mouse to (1020, 687)
# Moving mouse to (1041, 673)
# Moving mouse to (1024, 684)
# Moving mouse to (1033, 676)
# Moving mouse to (1030, 681)
# Moving mouse to (1040, 684)
# Moving mouse to (1048, 686)
# Moving mouse to (1036, 694)
# Moving mouse to (1043, 696)
# Moving mouse to (1035, 699)
# Moving mouse to (1054, 690)
# Moving mouse to (1052, 686)
# Moving mouse to (1032, 694)
# Moving mouse to (1053, 695)
# Moving mouse to (1065, 692)
# Moving mouse to (1042, 693)
# Moving mouse to (1044, 693)
# Moving mouse to (1032, 701)
# Moving mouse to (1059, 686)
# Moving mouse to (1400, 529)
# Moving mouse to (1468, 623)
# Moving mouse to (1401, 584)
# Moving mouse to (1306, 465)
# Moving mouse to (1394, 515)
# Moving mouse to (1333, 513)
# Moving mouse to (1417, 627)
# Moving mouse to (1460, 658)
# Moving mouse to (1449, 706)
# Moving mouse to (893, 576)
# Moving mouse to (1021, 353)
# Moving mouse to (1200, 164)
# Moving mouse to (1317, 217)
# Moving mouse to (1403, 225)
